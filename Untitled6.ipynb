# %% [markdown]
# **final project ANNA**

# %%
# ========================================
# STEP 1: Setup and Install Dependencies
# ========================================

# Install required libraries
# !pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu118
# !pip install flask pillow tqdm

import os
import zipfile
from pathlib import Path

# Path to your uploaded dataset
DATASET_ZIP = "/content/archive (2).zip"
EXTRACT_DIR = "/content/deepfake_dataset"

# Extract dataset if not already extracted
if not os.path.exists(EXTRACT_DIR):
    print("Extracting dataset...")
    with zipfile.ZipFile(DATASET_ZIP, 'r') as zip_ref:
        zip_ref.extractall(EXTRACT_DIR)
    print("✅ Extraction complete!")
else:
    print("✅ Dataset already extracted.")

# List extracted contents
print("\n📂 Extracted Folder Structure:")
for root, dirs, files in os.walk(EXTRACT_DIR):
    level = root.replace(EXTRACT_DIR, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = ' ' * 4 * (level + 1)
    for f in files[:5]:  # show only first 5 files per folder
        print(f"{subindent}{f}")
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
# Extracting dataset...
# ✅ Extraction complete!
#
# 📂 Extracted Folder Structure:
# deepfake_dataset/
#     rvf10k/
#         valid/
#             real/
#                 03718.jpg
#                 33921.jpg
#                 23417.jpg
#                 52334.jpg
#                 08504.jpg
#             fake/
#                 3XS35FGF71.jpg
#                 Q1AA9ZSHVW.jpg
#                 CIY3028CQF.jpg
#                 64VUFU73BQ.jpg
#                 AMR0BX0LMY.jpg
#         train/
#             real/
#                 04253.jpg
#                 56481.jpg
#                 20313.jpg
#                 33307.jpg
#                 40437.jpg
#             fake/
#                 9MGSOW9WQ8.jpg
#                 NRCOQ1KJCR.jpg
#                 RKDYDG6M9G.jpg
#                 FG4YNHXS8K.jpg
#                 5BMWWY6BQ8.jpg

# %%
# ========================================
# STEP 2: Data Loading and Preprocessing
# ========================================

import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# Define transformations (resize, normalize, augment)
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Dataset directory (from previous step)
DATA_DIR = "/content/deepfake_dataset/rvf10k"

# Load dataset using ImageFolder
full_dataset = datasets.ImageFolder(root=DATA_DIR, transform=transform)

# Split into train & validation (80-20)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Check data
print(f"✅ Total Images: {len(full_dataset)}")
print(f"🧠 Classes: {full_dataset.classes}")
print(f"📦 Train: {len(train_dataset)}, Val: {len(val_dataset)}")
# Out:
# ✅ Total Images: 10000
# 🧠 Classes: ['train', 'valid']
# 📦 Train: 8000, Val: 2000

# %%
# ========================================
# STEP 3: Define and Compare Models
# ========================================


import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models # Import models here

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---- Model 1: Simple CNN ----
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=2):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.flatten_dim = None  # will be computed dynamically
        self.fc1 = None
        self.fc2 = None
        self.num_classes = num_classes

    def _get_flatten_dim(self, x):
        with torch.no_grad():
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            # Calculate the flattened dimension based on the output shape
            return x.view(x.size(0), -1).size(1)


    def forward(self, x):
        # on first forward pass compute flatten dim and create FC layers
        if self.flatten_dim is None:
            self.flatten_dim = self._get_flatten_dim(x)
            self.fc1 = nn.Linear(self.flatten_dim, 128).to(x.device)
            self.fc2 = nn.Linear(128, self.num_classes).to(x.device)

        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x



# ---- Model 2: ResNet18 ----
def build_resnet(num_classes=2):
    model = models.resnet18(pretrained=True)
    for param in model.parameters():
        param.requires_grad = False  # freeze feature extractor
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model


# ---- Model 3: EfficientNet-B0 ----
def build_efficientnet(num_classes=2):
    model = models.efficientnet_b0(pretrained=True)
    for param in model.parameters():
        param.requires_grad = False
    model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
    return model


# Create dictionary of models
models_dict = {
    "SimpleCNN": SimpleCNN().to(device),
    "ResNet18": build_resnet().to(device),
    "EfficientNetB0": build_efficientnet().to(device)
}

print("✅ Models ready for training:", list(models_dict.keys()))
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# ========================================
# STEP 4: Training Function
# ========================================

import torch.optim as optim
from tqdm import tqdm

def train_model(model, train_loader, val_loader, epochs=3):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct, total = 0, 0

        for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}"):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = 100 * correct / total

        # Validation
        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, predicted = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
        val_acc = 100 * val_correct / val_total

        print(f"Epoch [{epoch+1}/{epochs}] | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}%")

    return val_acc

# %%
# ========================================
# STEP 5: Train and Compare All Models
# ========================================

best_model_name = None
best_acc = 0
results = {}

for name, model in models_dict.items():
    print(f"\n🚀 Training {name} ...")
    acc = train_model(model, train_loader, val_loader, epochs=3)
    results[name] = acc
    if acc > best_acc:
        best_acc = acc
        best_model_name = name

print("\n📈 Validation Accuracy Summary:")
for k, v in results.items():
    print(f"{k}: {v:.2f}%")

print(f"\n🏆 Best Model: {best_model_name} ({best_acc:.2f}%)")

# Save best model
torch.save(models_dict[best_model_name].state_dict(), f"/content/{best_model_name}_best.pth")
print(f"✅ Model saved: /content/{best_model_name}_best.pth")
# Out:
# 🚀 Training SimpleCNN ...
# Epoch 1/3: 100%|██████████| 250/250 [04:03<00:00,  1.03it/s]
# Epoch [1/3] | Train Acc: 69.96% | Val Acc: 70.05%
# Epoch 2/3: 100%|██████████| 250/250 [03:59<00:00,  1.04it/s]
# Epoch [2/3] | Train Acc: 69.99% | Val Acc: 70.05%
# Epoch 3/3: 100%|██████████| 250/250 [03:59<00:00,  1.04it/s]
# Epoch [3/3] | Train Acc: 69.99% | Val Acc: 70.05%
#
# 🚀 Training ResNet18 ...
# Epoch 1/3: 100%|██████████| 250/250 [04:31<00:00,  1.09s/it]
# Epoch [1/3] | Train Acc: 67.14% | Val Acc: 69.80%
# Epoch 2/3: 100%|██████████| 250/250 [04:31<00:00,  1.08s/it]
# Epoch [2/3] | Train Acc: 68.24% | Val Acc: 70.05%
# Epoch 3/3: 100%|██████████| 250/250 [04:31<00:00,  1.09s/it]
# Epoch [3/3] | Train Acc: 68.85% | Val Acc: 70.05%
#
# 🚀 Training EfficientNetB0 ...
# Epoch 1/3: 100%|██████████| 250/250 [03:49<00:00,  1.09it/s]
# Epoch [1/3] | Train Acc: 68.21% | Val Acc: 66.65%
# Epoch 2/3: 100%|██████████| 250/250 [03:54<00:00,  1.07it/s]
# ...

# %%
# ========================================
# STEP 6: Evaluation and Visualization
# ========================================
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Re-train or load best model
best_model = models_dict[best_model_name]
best_model.load_state_dict(torch.load(f"/content/{best_model_name}_best.pth"))
best_model.eval()

y_true = []
y_pred = []

with torch.no_grad():
    for imgs, labels in val_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = best_model(imgs)
        _, preds = torch.max(outputs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=full_dataset.classes, yticklabels=full_dataset.classes)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title(f"Confusion Matrix - {best_model_name}")
plt.show()

# Classification Report
print("\n📋 Classification Report:")
print(classification_report(y_true, y_pred, target_names=full_dataset.classes))
# Out:
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#        train       0.70      1.00      0.82      1401
#        valid       0.00      0.00      0.00       599
#
#     accuracy                           0.70      2000
#    macro avg       0.35      0.50      0.41      2000
# weighted avg       0.49      0.70      0.58      2000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# !pip install flask-ngrok
# Out:
# ...
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl.metadata (1.8 kB)
# ...

# %%
# !pip install streamlit --quiet
# !pip install pyngrok --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 105.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 94.1 MB/s eta 0:00:00

# %%
import torch

# Save your trained model
torch.save(model.state_dict(), "best_model.pth")

# %%
from google.colab import files
files.download("best_model.pth")
